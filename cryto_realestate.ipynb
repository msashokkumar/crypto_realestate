# %%
import pandas as pd
from pathlib import Path

# %%
# This dataframe will have:
# unit_id
# unit_address - lat/long
# unit_list_price in USD
# unit_sale_price in USD (if sold)
# unit_size (in sqft)
# unit_status - sold, available, etc.

# %%
# We will need to show an interactive map, where we can filter by locality, unit status or price range

# Locality - drop down list box
# Unit Status - Drop down list box
# Price Range - Slider

# %%
# FTX API

# For the selected unit - provide BITCOIN price - static
# Also, continuous stream of BITCOIN pricing for the listed unit

# %%
units_df = pd.read_json(Path('data/units.json'))
units_df
# Out:
#         id  project_id  floor_plan_id                        title  \
# 0       43           9             31                       Unit A
# 1       44           9             30                       Unit B
# 2       45           9             30                       Unit C
# 3       46           9             30                       Unit D
# 4       47           9             30                       Unit E
# ...    ...         ...            ...                          ...
# 1745  1961         277           1439  1119 N. American St. Unit 3
# 1746  1962         277           1440  1119 N. American St. Unit 4
# 1747  1963         277           1441  1119 N. American St. Unit 5
# 1748  1964         277           1442  1119 N. American St. Unit 6
# 1749  1965         277           1443  1119 N. American St. Unit 7
#
#      description   price     status  user_id promised_delivery_date  \
# 0           None  424000       sold    287.0             2017-05-01
# ...

# %%
units_addresses_df = pd.read_json(Path('data/unit_addresses.json'))
units_addresses_df
# Out:
#       id  unit_id              thoroughfare    locality administrative_area  \
# 0      1     2258        7051 E OBELISKS ST       Boise                  ID
# 1      2     2259   7014 E FAREWELL BEND CT       Boise                  ID
# 2     10     2470  14718 Garner Falls Trail      Humble                  TX
# 3     11     2471  14706 Garner Falls Trail      Humble                  TX
# 4    216     2660          2569 Bayrose Cir  East Point                  GA
# ..   ...      ...                       ...         ...                 ...
# 222  738     2839         675 Drewry Street     Atlanta                  GA
# 223  739     2882         675 Drewry Street     Atlanta                  GA
# 224  740     2864         675 Drewry Street     Atlanta                  GA
# 225  741     3463            220 Lake Shore  Palm Beach                  FL
# 226  742     2865         675 Drewry Street     Atlanta                  GA
#
# ...

# %%
projects_df = pd.read_json(Path('data/projects.json'))
projects_df
# Out:
#       id                                        title  user_id       status  \
# 0      3                         Green Nine Townhomes        1         None
# 1      5                                 Berks Street        1         None
# 2      6                                  Howard Park        9         None
# 3      7                    Quarters at Queen Village        9         None
# 4      8                        Le Vieux Carre Condos        9         None
# ..   ...                                          ...      ...          ...
# 413  426  The Residences at the Waldorf Astoria Miami     3743         None
# 414  427                                    Stillwood     3734  coming_soon
# 415  428                                Aria Reserve      3743         None
# 416  429                                   Okan Tower     3743         None
# 417  430                                        Aster        2         None
#
#                                             slug  \
# ...
